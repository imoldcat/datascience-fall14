# %% [markdown]
# ### The notebook plays with R [Nile data](http://stat.ethz.ch/R-manual/R-patched/library/datasets/html/Nile.html). The dataset has been downloaded in data directory. It contains the measurements of the annual river flow of Nile from 1871 to 1970.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plot

nile = pd.read_csv('../data/Nile.csv')
nile.plot(x='time', y='Nile', title='Nile River Flow')
